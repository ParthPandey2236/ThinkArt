# %%
import cv2
from pyrebase import pyrebase
from PIL import Image
import urllib.request as urllib2
#import request
urllib2.urlretrieve("https://firebasestorage.googleapis.com/v0/b/profiletest-8135c.appspot.com/o/parth%2Fimage_cropper_1607191988625.jpg?alt=media&token=3aea38c8-5eb7-4fa0-be71-5097b0e8d886", "sample.png")
#img_location = r'C:\\Users\\Parth Pandey\\OneDrive\\Desktop\\Stud-Bud\\AR1.jpg'
print(1)
img =cv2.imread("sample.png")
#img= Image.open(requests.get(https://firebasestorage.googleapis.com/v0/b/profiletest-8135c.appspot.com/o/parth%2Fimage_cropper_1607108411611.jpg?alt=media&token=43ab4628-605c-44a6-9719-f7349c65c98d,stream = True).raw)
print(img)
img= cv2.resize(img,(400,400))
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
inverted_gray_image = 255 - gray_image
blurred_img = cv2.GaussianBlur(inverted_gray_image, (21,21),0,0)
inverted_blurred_img = 255 - blurred_img
pencil_sketch_IMG = cv2.divide(gray_image, inverted_blurred_img, scale = 256.0)
# cv2.imshow('Original Image', img)
# cv2.imshow('Pencil Sketch', pencil_sketch_IMG)
# cv2.waitKey(0)
config = {
    "apiKey": "AIzaSyCvD5d45J9LNLVZtmDYSYFN16tCK7FqUac",
    "authDomain": "think-art.firebaseapp.com",
    "databaseURL": "xxxxxx",
    "projectId": "think-art",
    "storageBucket": "think-art.appspot.com",
    "messagingSenderId": "508686447517",
    "appId": "1:508686447517:web:1677b2f6c0ad54d9c13574",
    "measurementId": "G-JSY1TRC7L0"
  }
firebase = pyrebase.initialize_app(config)
storage = firebase.storage()
cv2.imwrite("testcase.png",pencil_sketch_IMG)
storage.child("testcase.png").put("testcase.png")
auth=firebase.auth()
email="parthpandey@gmail.com"
password = "123456789"
user= auth.sign_in_with_email_and_password(email,password)
url=storage.child("testcase.png").get_url(user['idToken'])
print(url)
# Out:
# 1
# [[[158 162 150]
#   [160 164 152]
#   [167 171 159]
#   ...
#   [152 154 125]
#   [154 153 125]
#   [145 144 116]]
#
#  [[156 160 148]
#   [158 162 150]
#   [165 169 157]
#   ...
#   [145 147 118]
#   [150 149 121]
#   [149 148 120]]
#
#  [[158 162 151]
#   [160 164 153]
#   [166 170 158]
#   ...
#   [145 147 118]
#   [149 148 120]
#   [150 149 121]]
#
#  ...
#
#  [[ 25  28  36]
#   [ 30  33  41]
#   [ 32  35  43]
#   ...
#   [ 30  45  54]
#   [ 31  43  53]
#   [ 29  41  51]]
#
#  [[ 23  26  34]
#   [ 28  31  39]
#   [ 33  36  44]
#   ...
#   [ 33  45  57]
#   [ 28  40  52]
#   [ 28  40  52]]
#
#  [[ 25  28  36]
#   [ 29  32  40]
#   [ 33  36  44]
#   ...
#   [ 28  40  52]
#   [ 18  30  42]
#   [ 25  37  49]]]
# ...
